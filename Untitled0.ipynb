# %%
import pandas as pd

qtr1 = {'India':150, 'USA': 200, 'Spain':300, 'UK':250}
qtr2 = {'India': 250, 'USA': 210, 'Australia':300, 'UK':400}

qtr1_series = pd.Series(qtr1)
qtr2_series = pd.Series(qtr2)

total = qtr1_series.add(qtr2_series, fill_value = 0)

disaster_data = total - (0.15*total)
print(total - disaster_data)
print(disaster_data)
# Out:
# Australia    45.0
# India        60.0
# Spain        45.0
# UK           97.5
# USA          61.5
# dtype: float64
# Australia    255.0
# India        340.0
# Spain        255.0
# UK           552.5
# USA          348.5
# dtype: float64

# %%
import pandas as pd
from google.colab import files


uploaded = files.upload()


df = {'Name':['Faiyaz', 'Faiyazv2', 'Faiyazv3'], 'Age':[12, 13, 14], 'Hobby':['Coding', 'Music', 'Books']}
df_ind = ['Student1', 'Student2', 'Student3']
df_df = pd.DataFrame(data = df, index = df_ind)
print(df_df)
# Out:
#               Name  Age   Hobby
# Student1    Faiyaz   12  Coding
# Student2  Faiyazv2   13   Music
# Student3  Faiyazv3   14   Books

# %%
x = pd.read_csv('C:/Users/faiya/Documents/Advertising.csv')
print(x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-35649a1ea2c2> in <module>()
# ----> 1 x = pd.read_csv('C:/Users/faiya/Documents/Advertising.csv')
#       2 print(x)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
x = pd.read_csv('C:/Users/faiya/Documents/Advertising.csv')
print(x)

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-e9c7f448-9669-4352-b107-05f83009dca6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9c7f448-9669-4352-b107-05f83009dca6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Advertising.csv to Advertising.csv

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['Advertising.csv']))
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-934c54a271de> in <module>()
#       2 import io
#       3
# ----> 4 df = pd.read_csv(io.BytesIO(uploaded['Advertising.csv']))
#       5 print(df)
#
# NameError: name 'uploaded' is not defined

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['tips.csv']))

df.loc[110]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-196c50613297> in <module>()
#       2 import io
#       3
# ----> 4 df = pd.read_csv(io.BytesIO(uploaded['tips.csv']))
#       5
#       6 df.loc[110]
#
# NameError: name 'uploaded' is not defined

# %%
df.loc[101]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ed7cb815f6c> in <module>()
# ----> 1 df.loc[101]
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv(io.BytesIO(uploaded['t']))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-a9ba32f0774e> in <module>
#       1 import pandas as pd
#       2
# ----> 3 pd.read_csv("hearing_test.csv")
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
