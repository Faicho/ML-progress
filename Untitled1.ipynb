# %%
import numpy as np
from matplotlib import image as img

x = img.imread("images.jfif")

np.shape(x)
# Out:
# (130, 173, 3)

# %%
y = img.imread("img1.png")
np.shape(y)
# Out:
# (318, 540, 4)

# %%
from matplotlib import pyplot as pt
pt.figure(figsize = (5, 5), dpi = 200)
pt.imshow(x)
pt.imshow(y)

# %%
t = (123,246,3)
type(t)
# Out:
# tuple

# %%
t1,t2,t3 = t

# %%
t2
# Out:
# 246

# %%
y4 = (t1,t2*t3)
y4
# Out:
# (123, 738)

# %% [markdown]
# 28/06/23 codeyoung class
# #Step1 : Convert the image into a numpy array
#
# #Step2 : Check the shape(3D)
# #The data type of the shape  will be a tuple
# #The data type of the file will be a numpy array
#
# #Step 3(Optional) : Convert the numpy array into an image
#
# #Step4 : Convert the 3D array into a 2D array (As the ML models cannot work with 3dimesnitons)
# #Break the tuple
# #Use the reshape method
# #Multiply the first two components
